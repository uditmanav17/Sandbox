# %% [markdown]
# ## [SQL Model](https://sqlmodel.tiangolo.com/)
#
# * [Tutorial](https://sqlmodel.tiangolo.com/tutorial/)

# %%
from typing import Optional, List

from sqlmodel import Field, SQLModel, create_engine, Session, select, Relationship

# %%
# for formatting and color

from pprint import pprint as pp
from pprint import pformat as pf
from termcolor import cprint
from colorama import Fore, Back, Style

# %%
sqlite_file_name = "database.db"
sqlite_url = f"sqlite:///{sqlite_file_name}"

engine = create_engine(sqlite_url, echo=True)


def create_db_and_tables():
    SQLModel.metadata.create_all(engine)

# %% [markdown]
# ## [Creating JOIN](https://sqlmodel.tiangolo.com/tutorial/connect/create-connected-tables/)

# %%
class Team(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    headquarters: str


class Hero(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    secret_name: str
    age: Optional[int] = None

    team_id: Optional[int] = Field(default=None, foreign_key="team.id")

# %%
create_db_and_tables()
# Out:
# 2021-09-08 17:13:57,624 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:13:57,626 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("team")
# 2021-09-08 17:13:57,627 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:13:57,631 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("team")
# 2021-09-08 17:13:57,631 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:13:57,632 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("hero")
# 2021-09-08 17:13:57,633 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:13:57,634 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("hero")
# 2021-09-08 17:13:57,635 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:13:57,636 INFO sqlalchemy.engine.Engine
# CREATE TABLE team (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	headquarters VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-09-08 17:13:57,637 INFO sqlalchemy.engine.Engine [no key 0.00074s] ()
# 2021-09-08 17:13:57,785 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_name ON team (name)
# 2021-09-08 17:13:57,787 INFO sqlalchemy.engine.Engine [no key 0.00158s] ()
# 2021-09-08 17:13:57,914 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_headquarters ON team (headquarters)
# 2021-09-08 17:13:57,915 INFO sqlalchemy.engine.Engine [no key 0.00077s] ()
# 2021-09-08 17:13:58,009 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_id ON team (id)
# 2021-09-08 17:13:58,011 INFO sqlalchemy.engine.Engine [no key 0.00216s] ()
# 2021-09-08 17:13:58,126 INFO sqlalchemy.engine.Engine
# CREATE TABLE hero (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	secret_name VARCHAR NOT NULL,
# 	age INTEGER,
# 	team_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(team_id) REFERENCES team (id)
# )
#
#
# 2021-09-08 17:13:58,126 INFO sqlalchemy.engine.Engine [no key 0.00128s] ()
# 2021-09-08 17:13:58,232 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_id ON hero (id)
# 2021-09-08 17:13:58,236 INFO sqlalchemy.engine.Engine [no key 0.00382s] ()
# 2021-09-08 17:13:58,337 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_name ON hero (name)
# 2021-09-08 17:13:58,338 INFO sqlalchemy.engine.Engine [no key 0.00060s] ()
# 2021-09-08 17:13:58,464 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_secret_name ON hero (secret_name)
# 2021-09-08 17:13:58,465 INFO sqlalchemy.engine.Engine [no key 0.00068s] ()
# 2021-09-08 17:13:58,582 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_age ON hero (age)
# 2021-09-08 17:13:58,583 INFO sqlalchemy.engine.Engine [no key 0.00080s] ()
# 2021-09-08 17:13:58,665 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_team_id ON hero (team_id)
# 2021-09-08 17:13:58,666 INFO sqlalchemy.engine.Engine [no key 0.00064s] ()
# 2021-09-08 17:13:58,771 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### [Creating Connected Rows](https://sqlmodel.tiangolo.com/tutorial/connect/create-connected-rows/)

# %%
def create_heroes():
    with Session(engine) as session:
        # creating teams
        team_preventers = Team(name="Preventers", headquarters="Sharp Tower")
        team_z_force = Team(name="Z-Force", headquarters="Sister Margaret’s Bar")
        session.add(team_preventers)
        session.add(team_z_force)
        session.commit()

        # creating heroes and assigning them to team
        hero_deadpond = Hero(
            name="Deadpond", secret_name="Dive Wilson", team_id=team_z_force.id
        )
        hero_rusty_man = Hero(
            name="Rusty-Man",
            secret_name="Tommy Sharp",
            age=48,
            team_id=team_preventers.id,
        )
        hero_spider_boy = Hero(name="Spider-Boy", secret_name="Pedro Parqueador")
        session.add(hero_deadpond)
        session.add(hero_rusty_man)
        session.add(hero_spider_boy)
        session.commit()

        # refresh objects and print them
        session.refresh(hero_deadpond)
        session.refresh(hero_rusty_man)
        session.refresh(hero_spider_boy)

        cprint(f"Created hero: {hero_deadpond}", "green")
        cprint(f"Created hero: {hero_rusty_man}", "green")
        cprint(f"Created hero: {hero_spider_boy}", "green")

# %%
create_heroes()
# Out:
# 2021-09-08 17:14:03,013 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:03,017 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:14:03,018 INFO sqlalchemy.engine.Engine [generated in 0.00135s] ('Preventers', 'Sharp Tower')
# 2021-09-08 17:14:03,023 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:14:03,024 INFO sqlalchemy.engine.Engine [cached since 0.006726s ago] ('Z-Force', 'Sister Margaret’s Bar')
# 2021-09-08 17:14:03,025 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:14:03,234 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:03,243 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:14:03,246 INFO sqlalchemy.engine.Engine [generated in 0.00384s] (2,)
# 2021-09-08 17:14:03,253 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:14:03,255 INFO sqlalchemy.engine.Engine [cached since 0.01224s ago] (1,)
# 2021-09-08 17:14:03,264 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:14:03,267 INFO sqlalchemy.engine.Engine [generated in 0.00299s] ('Deadpond', 'Dive Wilson', None, 2)
# 2021-09-08 17:14:03,276 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:14:03,279 INFO sqlalchemy.engine.Engine [cached since 0.01491s ago] ('Rusty-Man', 'Tommy Sharp', 48, 1)
# 2021-09-08 17:14:03,283 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:14:03,286 INFO sqlalchemy.engine.Engine [cached since 0.02221s ago] ('Spider-Boy', 'Pedro Parqueador', None, None)
# 2021-09-08 17:14:03,291 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:14:03,418 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:03,419 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:14:03,420 INFO sqlalchemy.engine.Engine [generated in 0.00057s] (1,)
# 2021-09-08 17:14:03,421 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:14:03,422 INFO sqlalchemy.engine.Engine [cached since 0.002536s ago] (2,)
# 2021-09-08 17:14:03,423 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:14:03,423 INFO sqlalchemy.engine.Engine [cached since 0.004038s ago] (3,)
# Created hero: secret_name='Dive Wilson' name='Deadpond' team_id=2 id=1 age=None
# Created hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=1 id=2 age=48
# Created hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=None id=3 age=None
# 2021-09-08 17:14:03,424 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### [Reading connected data](https://sqlmodel.tiangolo.com/tutorial/connect/read-connected-data/)

# %%
def select_heroes():
    with Session(engine) as session:
        statement = select(Hero, Team).where(Hero.team_id == Team.id)
        results = session.exec(statement)
        for hero, team in results:
            cprint(f"Hero: {hero} \n\tTeam: {team}\n", "green")

# %%
select_heroes()
# Out:
# 2021-09-08 17:14:08,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:08,103 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id, team.id AS id_1, team.name AS name_1, team.headquarters
# FROM hero, team
# WHERE hero.team_id = team.id
# 2021-09-08 17:14:08,104 INFO sqlalchemy.engine.Engine [no key 0.00080s] ()
# Hero: secret_name='Dive Wilson' name='Deadpond' team_id=2 id=1 age=None
# 	Team: name='Z-Force' headquarters='Sister Margaret’s Bar' id=2
#
# Hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=1 id=2 age=48
# 	Team: name='Preventers' headquarters='Sharp Tower' id=1
#
# 2021-09-08 17:14:08,105 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# joining tables, this is equivalent to above
def select_heroes():
    with Session(engine) as session:
        statement = select(Hero, Team).join(Team)
        results = session.exec(statement)
        for hero, team in results:
            cprint(f"Hero: {hero} \n\tTeam: {team}\n", "green")


select_heroes()
# Out:
# 2021-09-08 17:14:12,179 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:12,182 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id, team.id AS id_1, team.name AS name_1, team.headquarters
# FROM hero JOIN team ON team.id = hero.team_id
# 2021-09-08 17:14:12,183 INFO sqlalchemy.engine.Engine [no key 0.00107s] ()
# Hero: secret_name='Dive Wilson' name='Deadpond' team_id=2 id=1 age=None
# 	Team: name='Z-Force' headquarters='Sister Margaret’s Bar' id=2
#
# Hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=1 id=2 age=48
# 	Team: name='Preventers' headquarters='Sharp Tower' id=1
#
# 2021-09-08 17:14:12,185 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# left outer join
def select_heroes():
    with Session(engine) as session:
        statement = select(Hero, Team).join(Team, isouter=True)
        results = session.exec(statement)
        for hero, team in results:
            cprint(f"Hero: {hero} \n\tTeam: {team}\n", "green")


select_heroes()
# Out:
# 2021-09-08 17:14:15,846 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:15,847 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id, team.id AS id_1, team.name AS name_1, team.headquarters
# FROM hero LEFT OUTER JOIN team ON team.id = hero.team_id
# 2021-09-08 17:14:15,848 INFO sqlalchemy.engine.Engine [no key 0.00052s] ()
# Hero: secret_name='Dive Wilson' name='Deadpond' team_id=2 id=1 age=None
# 	Team: name='Z-Force' headquarters='Sister Margaret’s Bar' id=2
#
# Hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=1 id=2 age=48
# 	Team: name='Preventers' headquarters='Sharp Tower' id=1
#
# Hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=None id=3 age=None
# 	Team: None
#
# 2021-09-08 17:14:15,852 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Select Only Heroes But Join with Teams
# If we only put the Team in the .join() and not in the select() function, we would not get the team data.
# But we would still be able to filter the rows with it.
def select_heroes():
    with Session(engine) as session:
        statement = select(Hero).join(Team).where(Team.name == "Preventers")
        results = session.exec(statement)
        for hero in results:
            cprint(f"Hero: {hero}", "green")


select_heroes()
# Out:
# 2021-09-08 17:14:20,129 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:20,131 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero JOIN team ON team.id = hero.team_id
# WHERE team.name = ?
# 2021-09-08 17:14:20,131 INFO sqlalchemy.engine.Engine [no key 0.00073s] ('Preventers',)
# Hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=1 id=2 age=48
# 2021-09-08 17:14:20,133 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Include the Team
def select_heroes():
    with Session(engine) as session:
        statement = select(Hero, Team).join(Team).where(Team.name == "Preventers")
        results = session.exec(statement)
        for hero, team in results:
            cprint(f"Hero: {hero} \n\tTeam: {team}\n", "green")


select_heroes()
# Out:
# 2021-09-08 17:14:22,863 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:22,865 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id, team.id AS id_1, team.name AS name_1, team.headquarters
# FROM hero JOIN team ON team.id = hero.team_id
# WHERE team.name = ?
# 2021-09-08 17:14:22,865 INFO sqlalchemy.engine.Engine [no key 0.00067s] ('Preventers',)
# Hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=1 id=2 age=48
# 	Team: name='Preventers' headquarters='Sharp Tower' id=1
#
# 2021-09-08 17:14:22,867 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### [Update Data Connections](https://sqlmodel.tiangolo.com/tutorial/connect/update-data-connections/)

# %%
def update_spider_boy():
    with Session(engine) as session:
        # fetch hero and team
        hero_spider_boy = session.exec(
            select(Hero).where(Hero.name == "Spider-Boy")
        ).one()
        team_preventers = session.exec(
            select(Team).where(Team.name == "Preventers")
        ).one()
        cprint(f"Hero: {hero_spider_boy} \n\tTeam: {team_preventers}", "green")

        # update connection
        hero_spider_boy.team_id = team_preventers.id
        session.add(hero_spider_boy)
        # commit to db, update and print
        session.commit()
        session.refresh(hero_spider_boy)
        cprint(f"Updated Hero: {hero_spider_boy}", "green")


update_spider_boy()
# Out:
# 2021-09-08 17:14:27,395 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:27,397 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.name = ?
# 2021-09-08 17:14:27,398 INFO sqlalchemy.engine.Engine [no key 0.00112s] ('Spider-Boy',)
# 2021-09-08 17:14:27,400 INFO sqlalchemy.engine.Engine SELECT team.id, team.name, team.headquarters
# FROM team
# WHERE team.name = ?
# 2021-09-08 17:14:27,401 INFO sqlalchemy.engine.Engine [no key 0.00061s] ('Preventers',)
# Hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=None id=3 age=None
# 	Team: name='Preventers' headquarters='Sharp Tower' id=1
# 2021-09-08 17:14:27,403 INFO sqlalchemy.engine.Engine UPDATE hero SET team_id=? WHERE hero.id = ?
# 2021-09-08 17:14:27,403 INFO sqlalchemy.engine.Engine [generated in 0.00066s] (1, 3)
# 2021-09-08 17:14:27,406 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:14:27,905 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:27,905 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:14:27,906 INFO sqlalchemy.engine.Engine [cached since 24.49s ago] (3,)
# Updated Hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=1 id=3 age=None
# 2021-09-08 17:14:27,907 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### [Removing Data Connections](https://sqlmodel.tiangolo.com/tutorial/connect/remove-data-connections/)

# %%
def update_spider_boy():
    with Session(engine) as session:
        # fetch hero and team
        hero_spider_boy = session.exec(
            select(Hero).where(Hero.name == "Spider-Boy")
        ).one()
        cprint(f"Hero: {hero_spider_boy}", "green")

        # update connection
        hero_spider_boy.team_id = None
        session.add(hero_spider_boy)
        # commit to db, update and print
        session.commit()
        session.refresh(hero_spider_boy)
        cprint(f"Updated Hero: {hero_spider_boy}", "green")


update_spider_boy()
# Out:
# 2021-09-08 17:14:32,070 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:32,072 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.name = ?
# 2021-09-08 17:14:32,073 INFO sqlalchemy.engine.Engine [no key 0.00079s] ('Spider-Boy',)
# Hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=1 id=3 age=None
# 2021-09-08 17:14:32,075 INFO sqlalchemy.engine.Engine UPDATE hero SET team_id=? WHERE hero.id = ?
# 2021-09-08 17:14:32,076 INFO sqlalchemy.engine.Engine [cached since 4.673s ago] (None, 3)
# 2021-09-08 17:14:32,080 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:14:32,288 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:14:32,289 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:14:32,289 INFO sqlalchemy.engine.Engine [cached since 28.87s ago] (3,)
# Updated Hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=None id=3 age=None
# 2021-09-08 17:14:32,291 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ## [Relationships](https://sqlmodel.tiangolo.com/tutorial/relationship-attributes/define-relationships-attributes/)

# %%
# RESTART KERNEL, RE-IMPORT AND REMOVE DATABASE.DB
from sqlmodel import Relationship

# READ FOR CLARIFICATION - https://sqlmodel.tiangolo.com/tutorial/relationship-attributes/back-populates/
# SQLModel.metadata.drop_all(engine)
# SQLModel.metadata.clear()


class Team(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    headquarters: str

    heroes: List["Hero"] = Relationship(back_populates="team")


class Hero(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    secret_name: str
    age: Optional[int] = None

    team_id: Optional[int] = Field(default=None, foreign_key="team.id")
    team: Optional[Team] = Relationship(back_populates="heroes")


create_db_and_tables()
# Out:
# 2021-09-08 17:15:03,554 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:15:03,556 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("team")
# 2021-09-08 17:15:03,557 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:15:03,558 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("team")
# 2021-09-08 17:15:03,559 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:15:03,559 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("hero")
# 2021-09-08 17:15:03,560 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:15:03,560 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("hero")
# 2021-09-08 17:15:03,561 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:15:03,562 INFO sqlalchemy.engine.Engine
# CREATE TABLE team (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	headquarters VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-09-08 17:15:03,562 INFO sqlalchemy.engine.Engine [no key 0.00044s] ()
# 2021-09-08 17:15:03,635 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_name ON team (name)
# 2021-09-08 17:15:03,636 INFO sqlalchemy.engine.Engine [no key 0.00088s] ()
# 2021-09-08 17:15:03,742 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_headquarters ON team (headquarters)
# 2021-09-08 17:15:03,743 INFO sqlalchemy.engine.Engine [no key 0.00146s] ()
# 2021-09-08 17:15:03,836 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_id ON team (id)
# 2021-09-08 17:15:03,838 INFO sqlalchemy.engine.Engine [no key 0.00215s] ()
# 2021-09-08 17:15:04,055 INFO sqlalchemy.engine.Engine
# CREATE TABLE hero (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	secret_name VARCHAR NOT NULL,
# 	age INTEGER,
# 	team_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(team_id) REFERENCES team (id)
# )
#
#
# 2021-09-08 17:15:04,058 INFO sqlalchemy.engine.Engine [no key 0.00309s] ()
# 2021-09-08 17:15:04,291 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_age ON hero (age)
# 2021-09-08 17:15:04,291 INFO sqlalchemy.engine.Engine [no key 0.00051s] ()
# 2021-09-08 17:15:04,508 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_team_id ON hero (team_id)
# 2021-09-08 17:15:04,509 INFO sqlalchemy.engine.Engine [no key 0.00094s] ()
# 2021-09-08 17:15:04,735 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_id ON hero (id)
# 2021-09-08 17:15:04,736 INFO sqlalchemy.engine.Engine [no key 0.00091s] ()
# 2021-09-08 17:15:04,853 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_name ON hero (name)
# 2021-09-08 17:15:04,855 INFO sqlalchemy.engine.Engine [no key 0.00220s] ()
# 2021-09-08 17:15:04,969 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_secret_name ON hero (secret_name)
# 2021-09-08 17:15:04,969 INFO sqlalchemy.engine.Engine [no key 0.00055s] ()
# 2021-09-08 17:15:05,103 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### [Create/Update Relationships](https://sqlmodel.tiangolo.com/tutorial/relationship-attributes/create-and-update-relationships/)

# %%
def create_heroes():
    with Session(engine) as session:
        team_preventers = Team(name="Preventers", headquarters="Sharp Tower")
        team_z_force = Team(name="Z-Force", headquarters="Sister Margaret’s Bar")

        hero_deadpond = Hero(
            name="Deadpond", secret_name="Dive Wilson", team=team_z_force
        )
        hero_rusty_man = Hero(
            name="Rusty-Man", secret_name="Tommy Sharp", age=48, team=team_preventers
        )
        hero_spider_boy = Hero(name="Spider-Boy", secret_name="Pedro Parqueador")
        session.add(hero_deadpond)
        session.add(hero_rusty_man)
        session.add(hero_spider_boy)
        session.commit()

        session.refresh(hero_deadpond)
        session.refresh(hero_rusty_man)
        session.refresh(hero_spider_boy)

        cprint(f"Created hero: {hero_deadpond}", "green")
        cprint(f"Created hero: {hero_rusty_man}", "green")
        cprint(f"Created hero: {hero_spider_boy}", "green")

        hero_spider_boy.team = team_preventers
        session.add(hero_spider_boy)
        session.commit()


create_heroes()
# Out:
# 2021-09-08 17:15:07,026 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:15:07,027 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:15:07,028 INFO sqlalchemy.engine.Engine [generated in 0.00045s] ('Z-Force', 'Sister Margaret’s Bar')
# 2021-09-08 17:15:07,130 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:15:07,131 INFO sqlalchemy.engine.Engine [cached since 0.1037s ago] ('Preventers', 'Sharp Tower')
# 2021-09-08 17:15:07,132 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:15:07,132 INFO sqlalchemy.engine.Engine [generated in 0.00051s] ('Deadpond', 'Dive Wilson', None, 1)
# 2021-09-08 17:15:07,133 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:15:07,134 INFO sqlalchemy.engine.Engine [cached since 0.002244s ago] ('Rusty-Man', 'Tommy Sharp', 48, 2)
# 2021-09-08 17:15:07,135 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:15:07,136 INFO sqlalchemy.engine.Engine [cached since 0.004105s ago] ('Spider-Boy', 'Pedro Parqueador', None, None)
# 2021-09-08 17:15:07,137 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:15:07,253 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:15:07,258 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:15:07,259 INFO sqlalchemy.engine.Engine [generated in 0.00137s] (1,)
# 2021-09-08 17:15:07,263 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:15:07,265 INFO sqlalchemy.engine.Engine [cached since 0.007642s ago] (2,)
# 2021-09-08 17:15:07,269 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:15:07,270 INFO sqlalchemy.engine.Engine [cached since 0.01293s ago] (3,)
# Created hero: secret_name='Dive Wilson' name='Deadpond' team_id=1 age=None id=1
# Created hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=2 age=48 id=2
# Created hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=None age=None id=3
# 2021-09-08 17:15:07,280 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:15:07,286 INFO sqlalchemy.engine.Engine [generated in 0.00572s] (2,)
# 2021-09-08 17:15:07,297 INFO sqlalchemy.engine.Engine UPDATE hero SET team_id=? WHERE hero.id = ?
# 2021-09-08 17:15:07,301 INFO sqlalchemy.engine.Engine [generated in 0.00375s] (2, 3)
# 2021-09-08 17:15:07,321 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# There are several things to notice here.
#
# First, we create some Team instance objects. We want to use the IDs of these teams when creating the Hero instances, in the team_id field.
#
# But model instances don't have an ID generated by the database until we add and commit them to the session. Before that, they are just None, and we want to use the actual IDs.
#
# So, we have to add them and commit the session first, before we start creating the Hero instances, to be able to use their IDs.
#
# Then, we use those IDs when creating the Hero instances. We add the new heroes to the session, and then we commit them.
#
# So, we are committing twice. And we have to remember to add some things first, and then commit, and do all that in the right order, otherwise we could end up using a team.id that is currently None because it hasn't been saved.
#
# This is the first area where these relationship attributes can help.

# %%
with Session(engine) as session:
    session.execute("delete from hero;")
    session.execute("delete from team;")
    session.commit()
# Out:
# 2021-09-08 17:21:59,792 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:21:59,793 INFO sqlalchemy.engine.Engine delete from hero;
# 2021-09-08 17:21:59,793 INFO sqlalchemy.engine.Engine [generated in 0.00040s] ()
# 2021-09-08 17:21:59,797 INFO sqlalchemy.engine.Engine delete from team;
# 2021-09-08 17:21:59,797 INFO sqlalchemy.engine.Engine [generated in 0.00043s] ()
# 2021-09-08 17:21:59,798 INFO sqlalchemy.engine.Engine COMMIT

# %%
def create_heroes():
    with Session(engine) as session:
        # create teams
        team_preventers = Team(name="Preventers", headquarters="Sharp Tower")
        team_z_force = Team(name="Z-Force", headquarters="Sister Margaret’s Bar")

        # create heroes
        hero_deadpond = Hero(
            name="Deadpond", secret_name="Dive Wilson", team=team_z_force
        )
        hero_rusty_man = Hero(
            name="Rusty-Man", secret_name="Tommy Sharp", age=48, team=team_preventers
        )
        hero_spider_boy = Hero(name="Spider-Boy", secret_name="Pedro Parqueador")
        session.add(hero_deadpond)
        session.add(hero_rusty_man)
        session.add(hero_spider_boy)
        session.commit()

        # refresh objects
        session.refresh(hero_deadpond)
        session.refresh(hero_rusty_man)
        session.refresh(hero_spider_boy)

        cprint(f"Created hero: {hero_deadpond}", "green")
        cprint(f"Created hero: {hero_rusty_man}", "green")
        cprint(f"Created hero: {hero_spider_boy}", "green")

        # now we can update team without explictly specifying team.id
        hero_spider_boy.team = team_preventers
        session.add(hero_spider_boy)
        session.commit()
        session.refresh(hero_spider_boy)
        cprint(f"Updated hero: {hero_spider_boy}", "green")

        # creating a team with heroes
        hero_black_lion = Hero(name="Black Lion", secret_name="Trevor Challa", age=35)
        hero_sure_e = Hero(name="Princess Sure-E", secret_name="Sure-E")
        team_wakaland = Team(
            name="Wakaland",
            headquarters="Wakaland Capital City",
            heroes=[hero_black_lion, hero_sure_e],
        )
        session.add(team_wakaland)
        session.commit()
        session.refresh(team_wakaland)
        cprint(pf(f"Team Wakaland: {team_wakaland}"), "green")

        # include relationship object in many side
        hero_tarantula = Hero(name="Tarantula", secret_name="Natalia Roman-on", age=32)
        hero_dr_weird = Hero(name="Dr. Weird", secret_name="Steve Weird", age=36)
        hero_cap = Hero(
            name="Captain North America", secret_name="Esteban Rogelios", age=93
        )

        team_preventers.heroes.append(hero_tarantula)
        team_preventers.heroes.append(hero_dr_weird)
        team_preventers.heroes.append(hero_cap)
        session.add(team_preventers)
        session.commit()
        session.refresh(hero_tarantula)
        session.refresh(hero_dr_weird)
        session.refresh(hero_cap)
        cprint(f"Preventers new hero: {hero_tarantula}", "green")
        cprint(f"Preventers new hero: {hero_dr_weird}", "green")
        cprint(f"Preventers new hero: {hero_cap}", "green")


create_heroes()
# Out:
# 2021-09-08 17:22:02,963 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:02,964 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:22:02,966 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] ('Z-Force', 'Sister Margaret’s Bar')
# 2021-09-08 17:22:02,981 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:22:02,982 INFO sqlalchemy.engine.Engine [cached since 416s ago] ('Preventers', 'Sharp Tower')
# 2021-09-08 17:22:02,983 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:02,984 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] ('Deadpond', 'Dive Wilson', None, 1)
# 2021-09-08 17:22:02,986 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:02,986 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] ('Rusty-Man', 'Tommy Sharp', 48, 2)
# 2021-09-08 17:22:02,987 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:02,988 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] ('Spider-Boy', 'Pedro Parqueador', None, None)
# 2021-09-08 17:22:02,989 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:22:03,164 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:03,165 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:03,166 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] (1,)
# 2021-09-08 17:22:03,168 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:03,169 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] (2,)
# 2021-09-08 17:22:03,171 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:03,172 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] (3,)
# Created hero: secret_name='Dive Wilson' name='Deadpond' team_id=1 age=None id=1
# Created hero: secret_name='Tommy Sharp' name='Rusty-Man' team_id=2 age=48 id=2
# Created hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=None age=None id=3
# 2021-09-08 17:22:03,174 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:22:03,176 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] (2,)
# 2021-09-08 17:22:03,178 INFO sqlalchemy.engine.Engine UPDATE hero SET team_id=? WHERE hero.id = ?
# 2021-09-08 17:22:03,179 INFO sqlalchemy.engine.Engine [cached since 415.9s ago] (2, 3)
# 2021-09-08 17:22:03,181 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:22:03,307 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:03,309 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:03,309 INFO sqlalchemy.engine.Engine [cached since 416.1s ago] (3,)
# Updated hero: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=2 age=None id=3
# 2021-09-08 17:22:03,311 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:22:03,312 INFO sqlalchemy.engine.Engine [cached since 416.3s ago] ('Wakaland', 'Wakaland Capital City')
# 2021-09-08 17:22:03,315 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:03,316 INFO sqlalchemy.engine.Engine [cached since 416.2s ago] ('Black Lion', 'Trevor Challa', 35, 3)
# 2021-09-08 17:22:03,317 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:03,317 INFO sqlalchemy.engine.Engine [cached since 416.2s ago] ('Princess Sure-E', 'Sure-E', None, 3)
# 2021-09-08 17:22:03,318 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:22:03,442 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:03,444 INFO sqlalchemy.engine.Engine SELECT team.id, team.name, team.headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:22:03,444 INFO sqlalchemy.engine.Engine [cached since 408.6s ago] (3,)
# "Team Wakaland: headquarters='Wakaland Capital City' id=3 name='Wakaland'"
# 2021-09-08 17:22:03,448 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:22:03,449 INFO sqlalchemy.engine.Engine [cached since 408.6s ago] (2,)
# 2021-09-08 17:22:03,450 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age, hero.team_id AS hero_team_id
# FROM hero
# WHERE ? = hero.team_id
# 2021-09-08 17:22:03,451 INFO sqlalchemy.engine.Engine [cached since 408.6s ago] (2,)
# 2021-09-08 17:22:03,452 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:03,453 INFO sqlalchemy.engine.Engine [cached since 416.3s ago] ('Tarantula', 'Natalia Roman-on', 32, 2)
# 2021-09-08 17:22:03,455 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:03,456 INFO sqlalchemy.engine.Engine [cached since 416.3s ago] ('Dr. Weird', 'Steve Weird', 36, 2)
# 2021-09-08 17:22:03,457 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age, team_id) VALUES (?, ?, ?, ?)
# 2021-09-08 17:22:03,458 INFO sqlalchemy.engine.Engine [cached since 416.3s ago] ('Captain North America', 'Esteban Rogelios', 93, 2)
# 2021-09-08 17:22:03,459 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:22:03,570 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:03,571 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:03,572 INFO sqlalchemy.engine.Engine [cached since 416.3s ago] (6,)
# 2021-09-08 17:22:03,575 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:03,576 INFO sqlalchemy.engine.Engine [cached since 416.3s ago] (7,)
# 2021-09-08 17:22:03,578 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:03,579 INFO sqlalchemy.engine.Engine [cached since 416.3s ago] (8,)
# Preventers new hero: secret_name='Natalia Roman-on' name='Tarantula' team_id=2 age=32 id=6
# Preventers new hero: secret_name='Steve Weird' name='Dr. Weird' team_id=2 age=36 id=7
# Preventers new hero: secret_name='Esteban Rogelios' name='Captain North America' team_id=2 age=93 id=8
# 2021-09-08 17:22:03,582 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### [Reading Relationships](https://sqlmodel.tiangolo.com/tutorial/relationship-attributes/read-relationships/)

# %%
# easier way to fetch hero's team
def select_heroes():
    with Session(engine) as session:
        statement = select(Hero).where(Hero.name == "Spider-Boy")
        result = session.exec(statement)
        hero_spider_boy = result.one()

        cprint(f"Spider-Boy's team again: {hero_spider_boy.team}", "green")


select_heroes()
# Out:
# 2021-09-08 17:22:06,973 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:06,975 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.name = ?
# 2021-09-08 17:22:06,976 INFO sqlalchemy.engine.Engine [no key 0.00099s] ('Spider-Boy',)
# 2021-09-08 17:22:06,978 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:22:06,979 INFO sqlalchemy.engine.Engine [generated in 0.00070s] (2,)
# Spider-Boy's team again: headquarters='Sharp Tower' id=2 name='Preventers'
# 2021-09-08 17:22:06,980 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# all heroes of team
def select_heroes():
    with Session(engine) as session:
        statement = select(Team).where(Team.name == "Preventers")
        result = session.exec(statement)
        team_preventers = result.one()
        cprint("Preventers heroes:", "green")
        cprint(pf(team_preventers.heroes), "green")


select_heroes()
# Out:
# 2021-09-08 17:22:09,977 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:09,979 INFO sqlalchemy.engine.Engine SELECT team.id, team.name, team.headquarters
# FROM team
# WHERE team.name = ?
# 2021-09-08 17:22:09,980 INFO sqlalchemy.engine.Engine [no key 0.00092s] ('Preventers',)
# Preventers heroes:
# 2021-09-08 17:22:09,982 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age, hero.team_id AS hero_team_id
# FROM hero
# WHERE ? = hero.team_id
# 2021-09-08 17:22:09,983 INFO sqlalchemy.engine.Engine [cached since 415.2s ago] (2,)
# [Hero(secret_name='Tommy Sharp', name='Rusty-Man', team_id=2, age=48, id=2),
#  Hero(secret_name='Pedro Parqueador', name='Spider-Boy', team_id=2, age=None, id=3),
#  Hero(secret_name='Natalia Roman-on', name='Tarantula', team_id=2, age=32, id=6),
#  Hero(secret_name='Steve Weird', name='Dr. Weird', team_id=2, age=36, id=7),
#  Hero(secret_name='Esteban Rogelios', name='Captain North America', team_id=2, age=93, id=8)]
# 2021-09-08 17:22:09,984 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### [Removing Relationships](https://sqlmodel.tiangolo.com/tutorial/relationship-attributes/remove-relationships/)

# %%
# Same as previous
def update_heroes():
    with Session(engine) as session:
        statement = select(Hero).where(Hero.name == "Spider-Boy")
        result = session.exec(statement)
        hero_spider_boy = result.one()

        hero_spider_boy.team = None
        session.add(hero_spider_boy)
        session.commit()

        session.refresh(hero_spider_boy)
        cprint(f"Spider-Boy without team: {hero_spider_boy}", "green")


update_heroes()
# Out:
# 2021-09-08 17:22:14,521 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:14,522 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.name = ?
# 2021-09-08 17:22:14,523 INFO sqlalchemy.engine.Engine [no key 0.00076s] ('Spider-Boy',)
# 2021-09-08 17:22:14,525 INFO sqlalchemy.engine.Engine UPDATE hero SET team_id=? WHERE hero.id = ?
# 2021-09-08 17:22:14,526 INFO sqlalchemy.engine.Engine [cached since 427.2s ago] (None, 3)
# 2021-09-08 17:22:14,529 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:22:14,717 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:22:14,718 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age, hero.team_id
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:22:14,718 INFO sqlalchemy.engine.Engine [cached since 427.5s ago] (3,)
# Spider-Boy without team: secret_name='Pedro Parqueador' name='Spider-Boy' team_id=None age=None id=3
# 2021-09-08 17:22:14,720 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### Important Reading
# ### [Relationship Back populates](https://sqlmodel.tiangolo.com/tutorial/relationship-attributes/back-populates/)
# ### [Type annotation strings](https://sqlmodel.tiangolo.com/tutorial/relationship-attributes/type-annotation-strings/)

# %% [markdown]
# ## Many to Many Relationships
# ### [Create Models with a Many-to-Many Link](https://sqlmodel.tiangolo.com/tutorial/many-to-many/create-models-with-link/)

# %%
# RESTART KERNEL, RE-IMPORT AND REMOVE DATABASE.DB
class HeroTeamLink(SQLModel, table=True):
    team_id: Optional[int] = Field(default=None, foreign_key="team.id", primary_key=True)
    hero_id: Optional[int] = Field(default=None, foreign_key="hero.id", primary_key=True)


class Team(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    headquarters: str
    # added link model to HeroTeamLink for storing many to many relationships
    heroes: List["Hero"] = Relationship(back_populates="teams", link_model=HeroTeamLink)


class Hero(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    secret_name: str
    age: Optional[int] = None
    # added link model to HeroTeamLink for storing many to many relationships
    teams: List[Team] = Relationship(back_populates="heroes", link_model=HeroTeamLink)


create_db_and_tables()
# Out:
# 2021-09-08 17:24:04,921 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:24:04,924 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("heroteamlink")
# 2021-09-08 17:24:04,925 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:24:04,927 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("heroteamlink")
# 2021-09-08 17:24:04,927 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:24:04,928 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("team")
# 2021-09-08 17:24:04,928 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:24:04,929 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("team")
# 2021-09-08 17:24:04,930 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:24:04,930 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("hero")
# 2021-09-08 17:24:04,931 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:24:04,932 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("hero")
# 2021-09-08 17:24:04,932 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:24:04,933 INFO sqlalchemy.engine.Engine
# CREATE TABLE team (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	headquarters VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-09-08 17:24:04,933 INFO sqlalchemy.engine.Engine [no key 0.00037s] ()
# 2021-09-08 17:24:05,089 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_headquarters ON team (headquarters)
# 2021-09-08 17:24:05,091 INFO sqlalchemy.engine.Engine [no key 0.00126s] ()
# 2021-09-08 17:24:05,216 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_name ON team (name)
# 2021-09-08 17:24:05,217 INFO sqlalchemy.engine.Engine [no key 0.00081s] ()
# 2021-09-08 17:24:05,340 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_id ON team (id)
# 2021-09-08 17:24:05,342 INFO sqlalchemy.engine.Engine [no key 0.00244s] ()
# 2021-09-08 17:24:05,457 INFO sqlalchemy.engine.Engine
# CREATE TABLE hero (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	secret_name VARCHAR NOT NULL,
# 	age INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-09-08 17:24:05,458 INFO sqlalchemy.engine.Engine [no key 0.00047s] ()
# 2021-09-08 17:24:05,562 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_age ON hero (age)
# 2021-09-08 17:24:05,563 INFO sqlalchemy.engine.Engine [no key 0.00056s] ()
# 2021-09-08 17:24:05,670 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_secret_name ON hero (secret_name)
# 2021-09-08 17:24:05,670 INFO sqlalchemy.engine.Engine [no key 0.00051s] ()
# 2021-09-08 17:24:05,774 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_id ON hero (id)
# 2021-09-08 17:24:05,775 INFO sqlalchemy.engine.Engine [no key 0.00068s] ()
# 2021-09-08 17:24:05,881 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_name ON hero (name)
# 2021-09-08 17:24:05,882 INFO sqlalchemy.engine.Engine [no key 0.00080s] ()
# 2021-09-08 17:24:05,986 INFO sqlalchemy.engine.Engine
# CREATE TABLE heroteamlink (
# 	team_id INTEGER,
# 	hero_id INTEGER,
# 	PRIMARY KEY (team_id, hero_id),
# 	FOREIGN KEY(team_id) REFERENCES team (id),
# 	FOREIGN KEY(hero_id) REFERENCES hero (id)
# )
#
#
# 2021-09-08 17:24:05,987 INFO sqlalchemy.engine.Engine [no key 0.00110s] ()
# 2021-09-08 17:24:06,093 INFO sqlalchemy.engine.Engine CREATE INDEX ix_heroteamlink_hero_id ON heroteamlink (hero_id)
# 2021-09-08 17:24:06,093 INFO sqlalchemy.engine.Engine [no key 0.00049s] ()
# 2021-09-08 17:24:06,198 INFO sqlalchemy.engine.Engine CREATE INDEX ix_heroteamlink_team_id ON heroteamlink (team_id)
# 2021-09-08 17:24:06,199 INFO sqlalchemy.engine.Engine [no key 0.00051s] ()
# 2021-09-08 17:24:06,305 INFO sqlalchemy.engine.Engine COMMIT

# %%
def create_heroes():
    with Session(engine) as session:
        team_preventers = Team(name="Preventers", headquarters="Sharp Tower")
        team_z_force = Team(name="Z-Force", headquarters="Sister Margaret’s Bar")

        hero_deadpond = Hero(
            name="Deadpond",
            secret_name="Dive Wilson",
            teams=[team_z_force, team_preventers],
        )
        hero_rusty_man = Hero(
            name="Rusty-Man",
            secret_name="Tommy Sharp",
            age=48,
            teams=[team_preventers],
        )
        hero_spider_boy = Hero(
            name="Spider-Boy", secret_name="Pedro Parqueador", teams=[team_preventers]
        )

        session.add(hero_deadpond)
        session.add(hero_rusty_man)
        session.add(hero_spider_boy)
        session.commit()

        session.refresh(hero_deadpond)
        session.refresh(hero_rusty_man)
        session.refresh(hero_spider_boy)

        cprint(f"Deadpond: {hero_deadpond}", "green")
        cprint(f"Rusty-Man: {hero_rusty_man}", "green")
        cprint(f"\tRusty-Man Teams: {hero_rusty_man.teams}", "green")
        cprint(f"Spider-Boy: {hero_spider_boy}", "green")
        cprint(f"Spider-Boy Teams: {hero_spider_boy.teams}", "green")


create_heroes()
# Out:
# 2021-09-08 17:29:35,620 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:35,621 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:29:35,621 INFO sqlalchemy.engine.Engine [cached since 327.8s ago] ('Deadpond', 'Dive Wilson', None)
# 2021-09-08 17:29:35,624 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:29:35,625 INFO sqlalchemy.engine.Engine [cached since 327.8s ago] ('Rusty-Man', 'Tommy Sharp', 48)
# 2021-09-08 17:29:35,626 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:29:35,627 INFO sqlalchemy.engine.Engine [cached since 327.8s ago] ('Spider-Boy', 'Pedro Parqueador', None)
# 2021-09-08 17:29:35,628 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:29:35,629 INFO sqlalchemy.engine.Engine [cached since 327.8s ago] ('Z-Force', 'Sister Margaret’s Bar')
# 2021-09-08 17:29:35,630 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:29:35,630 INFO sqlalchemy.engine.Engine [cached since 327.8s ago] ('Preventers', 'Sharp Tower')
# 2021-09-08 17:29:35,631 INFO sqlalchemy.engine.Engine INSERT INTO heroteamlink (team_id, hero_id) VALUES (?, ?)
# 2021-09-08 17:29:35,632 INFO sqlalchemy.engine.Engine [cached since 327.8s ago] ((2, 3), (2, 2), (1, 1), (2, 1))
# 2021-09-08 17:29:35,633 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:29:36,076 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:36,078 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:36,078 INFO sqlalchemy.engine.Engine [cached since 328s ago] (1,)
# 2021-09-08 17:29:36,080 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:36,081 INFO sqlalchemy.engine.Engine [cached since 328s ago] (2,)
# 2021-09-08 17:29:36,082 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:36,083 INFO sqlalchemy.engine.Engine [cached since 328s ago] (3,)
# Deadpond: secret_name='Dive Wilson' id=1 age=None name='Deadpond'
# Rusty-Man: secret_name='Tommy Sharp' id=2 age=48 name='Rusty-Man'
# 2021-09-08 17:29:36,085 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team, heroteamlink
# WHERE ? = heroteamlink.hero_id AND team.id = heroteamlink.team_id
# 2021-09-08 17:29:36,085 INFO sqlalchemy.engine.Engine [cached since 328s ago] (2,)
# 	Rusty-Man Teams: [Team(name='Preventers', id=2, headquarters='Sharp Tower')]
# Spider-Boy: secret_name='Pedro Parqueador' id=3 age=None name='Spider-Boy'
# 2021-09-08 17:29:36,087 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team, heroteamlink
# WHERE ? = heroteamlink.hero_id AND team.id = heroteamlink.team_id
# 2021-09-08 17:29:36,088 INFO sqlalchemy.engine.Engine [cached since 328s ago] (3,)
# Spider-Boy Teams: [Team(name='Preventers', id=2, headquarters='Sharp Tower')]
# 2021-09-08 17:29:36,089 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
with Session(engine) as session:
    session.execute("delete from hero;")
    session.execute("delete from team;")
    session.execute("delete from heroteamlink;")
    session.commit()
# Out:
# 2021-09-08 17:29:38,610 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:38,611 INFO sqlalchemy.engine.Engine delete from hero;
# 2021-09-08 17:29:38,612 INFO sqlalchemy.engine.Engine [cached since 166.4s ago] ()
# 2021-09-08 17:29:38,615 INFO sqlalchemy.engine.Engine delete from team;
# 2021-09-08 17:29:38,616 INFO sqlalchemy.engine.Engine [cached since 166.4s ago] ()
# 2021-09-08 17:29:38,617 INFO sqlalchemy.engine.Engine delete from heroteamlink;
# 2021-09-08 17:29:38,618 INFO sqlalchemy.engine.Engine [cached since 7.568s ago] ()
# 2021-09-08 17:29:38,619 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### [Creating Many-to-Many Relationships](https://sqlmodel.tiangolo.com/tutorial/many-to-many/create-data/)

# %%
def create_heroes():
    with Session(engine) as session:
        team_preventers = Team(name="Preventers", headquarters="Sharp Tower")
        team_z_force = Team(name="Z-Force", headquarters="Sister Margaret’s Bar")

        hero_deadpond = Hero(
            name="Deadpond",
            secret_name="Dive Wilson",
            teams=[team_z_force, team_preventers],
        )
        hero_rusty_man = Hero(
            name="Rusty-Man",
            secret_name="Tommy Sharp",
            age=48,
            teams=[team_preventers],
        )
        hero_spider_boy = Hero(
            name="Spider-Boy", secret_name="Pedro Parqueador", teams=[team_preventers]
        )
        session.add(hero_deadpond)
        session.add(hero_rusty_man)
        session.add(hero_spider_boy)
        session.commit()

        session.refresh(hero_deadpond)
        session.refresh(hero_rusty_man)
        session.refresh(hero_spider_boy)

        cprint(f"Deadpond: {hero_deadpond}", "green")
        cprint(f"Deadpond teams: {hero_deadpond.teams}", "green")
        cprint(f"Rusty-Man: {hero_rusty_man}", "green")
        cprint(f"Rusty-Man Teams: {hero_rusty_man.teams}", "green")
        cprint(f"Spider-Boy: {hero_spider_boy}", "green")
        cprint(f"Spider-Boy Teams: {hero_spider_boy.teams}", "green")


create_heroes()
# Out:
# 2021-09-08 17:29:40,279 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:40,280 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:29:40,281 INFO sqlalchemy.engine.Engine [cached since 332.4s ago] ('Deadpond', 'Dive Wilson', None)
# 2021-09-08 17:29:40,428 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:29:40,429 INFO sqlalchemy.engine.Engine [cached since 332.6s ago] ('Rusty-Man', 'Tommy Sharp', 48)
# 2021-09-08 17:29:40,430 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:29:40,432 INFO sqlalchemy.engine.Engine [cached since 332.6s ago] ('Spider-Boy', 'Pedro Parqueador', None)
# 2021-09-08 17:29:40,433 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:29:40,434 INFO sqlalchemy.engine.Engine [cached since 332.6s ago] ('Z-Force', 'Sister Margaret’s Bar')
# 2021-09-08 17:29:40,436 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:29:40,438 INFO sqlalchemy.engine.Engine [cached since 332.6s ago] ('Preventers', 'Sharp Tower')
# 2021-09-08 17:29:40,440 INFO sqlalchemy.engine.Engine INSERT INTO heroteamlink (team_id, hero_id) VALUES (?, ?)
# 2021-09-08 17:29:40,441 INFO sqlalchemy.engine.Engine [cached since 332.6s ago] ((1, 1), (2, 1), (2, 3), (2, 2))
# 2021-09-08 17:29:40,446 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:29:40,578 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:40,579 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:40,579 INFO sqlalchemy.engine.Engine [cached since 332.5s ago] (1,)
# 2021-09-08 17:29:40,581 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:40,581 INFO sqlalchemy.engine.Engine [cached since 332.5s ago] (2,)
# 2021-09-08 17:29:40,583 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:40,584 INFO sqlalchemy.engine.Engine [cached since 332.5s ago] (3,)
# Deadpond: secret_name='Dive Wilson' id=1 age=None name='Deadpond'
# 2021-09-08 17:29:40,586 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team, heroteamlink
# WHERE ? = heroteamlink.hero_id AND team.id = heroteamlink.team_id
# 2021-09-08 17:29:40,587 INFO sqlalchemy.engine.Engine [cached since 332.5s ago] (1,)
# Deadpond teams: [Team(name='Z-Force', id=1, headquarters='Sister Margaret’s Bar'), Team(name='Preventers', id=2, headquarters='Sharp Tower')]
# Rusty-Man: secret_name='Tommy Sharp' id=2 age=48 name='Rusty-Man'
# 2021-09-08 17:29:40,589 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team, heroteamlink
# WHERE ? = heroteamlink.hero_id AND team.id = heroteamlink.team_id
# 2021-09-08 17:29:40,590 INFO sqlalchemy.engine.Engine [cached since 332.5s ago] (2,)
# Rusty-Man Teams: [Team(name='Preventers', id=2, headquarters='Sharp Tower')]
# Spider-Boy: secret_name='Pedro Parqueador' id=3 age=None name='Spider-Boy'
# 2021-09-08 17:29:40,592 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team, heroteamlink
# WHERE ? = heroteamlink.hero_id AND team.id = heroteamlink.team_id
# 2021-09-08 17:29:40,593 INFO sqlalchemy.engine.Engine [cached since 332.5s ago] (3,)
# Spider-Boy Teams: [Team(name='Preventers', id=2, headquarters='Sharp Tower')]
# 2021-09-08 17:29:40,594 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### [Update and Remove Many-to-Many Relationships](https://sqlmodel.tiangolo.com/tutorial/many-to-many/update-remove-relationships/)

# %%
def update_heroes():
    with Session(engine) as session:
        # fetch records to update
        hero_spider_boy = session.exec(
            select(Hero).where(Hero.name == "Spider-Boy")
        ).one()
        team_z_force = session.exec(select(Team).where(Team.name == "Z-Force")).one()

        # add hero_spider_boy to team_z_force
        team_z_force.heroes.append(hero_spider_boy)
        session.add(team_z_force)
        session.commit()

        # check objects
        cprint(f"Updated Spider-Boy's Teams: {hero_spider_boy.teams}", "green")
        cprint(f"Z-Force heroes: {team_z_force.heroes}", "green")

        #
        hero_spider_boy.teams.remove(team_z_force)
        session.add(team_z_force)
        session.commit()

        cprint(f"Reverted Z-Force's heroes: {team_z_force.heroes}", "green")
        cprint(f"Reverted Spider-Boy's teams: {hero_spider_boy.teams}", "green")


update_heroes()
# Out:
# 2021-09-08 17:29:43,794 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:43,796 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.name = ?
# 2021-09-08 17:29:43,797 INFO sqlalchemy.engine.Engine [no key 0.00090s] ('Spider-Boy',)
# 2021-09-08 17:29:43,799 INFO sqlalchemy.engine.Engine SELECT team.id, team.name, team.headquarters
# FROM team
# WHERE team.name = ?
# 2021-09-08 17:29:43,800 INFO sqlalchemy.engine.Engine [no key 0.00072s] ('Z-Force',)
# 2021-09-08 17:29:43,802 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero, heroteamlink
# WHERE ? = heroteamlink.team_id AND hero.id = heroteamlink.hero_id
# 2021-09-08 17:29:43,803 INFO sqlalchemy.engine.Engine [generated in 0.00050s] (1,)
# 2021-09-08 17:29:43,804 INFO sqlalchemy.engine.Engine INSERT INTO heroteamlink (team_id, hero_id) VALUES (?, ?)
# 2021-09-08 17:29:43,805 INFO sqlalchemy.engine.Engine [generated in 0.00056s] (1, 3)
# 2021-09-08 17:29:43,809 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:29:43,993 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:43,995 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:43,995 INFO sqlalchemy.engine.Engine [generated in 0.00044s] (3,)
# 2021-09-08 17:29:43,996 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team, heroteamlink
# WHERE ? = heroteamlink.hero_id AND team.id = heroteamlink.team_id
# 2021-09-08 17:29:43,997 INFO sqlalchemy.engine.Engine [cached since 335.9s ago] (3,)
# Updated Spider-Boy's Teams: [Team(name='Preventers', id=2, headquarters='Sharp Tower'), Team(name='Z-Force', id=1, headquarters='Sister Margaret’s Bar')]
# 2021-09-08 17:29:43,998 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero, heroteamlink
# WHERE ? = heroteamlink.team_id AND hero.id = heroteamlink.hero_id
# 2021-09-08 17:29:43,999 INFO sqlalchemy.engine.Engine [cached since 0.1968s ago] (1,)
# Z-Force heroes: [Hero(secret_name='Dive Wilson', id=1, age=None, name='Deadpond'), Hero(secret_name='Pedro Parqueador', id=3, name='Spider-Boy', age=None, teams=[Team(name='Preventers', id=2, headquarters='Sharp Tower'), Team(name='Z-Force', id=1, headquarters='Sister Margaret’s Bar', heroes=[...])])]
# 2021-09-08 17:29:44,001 INFO sqlalchemy.engine.Engine DELETE FROM heroteamlink WHERE heroteamlink.team_id = ? AND heroteamlink.hero_id = ?
# 2021-09-08 17:29:44,002 INFO sqlalchemy.engine.Engine [generated in 0.00052s] (1, 3)
# 2021-09-08 17:29:44,004 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:29:44,142 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:29:44,147 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:29:44,149 INFO sqlalchemy.engine.Engine [generated in 0.00235s] (1,)
# 2021-09-08 17:29:44,155 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero, heroteamlink
# WHERE ? = heroteamlink.team_id AND hero.id = heroteamlink.hero_id
# 2021-09-08 17:29:44,158 INFO sqlalchemy.engine.Engine [cached since 0.3553s ago] (1,)
# Reverted Z-Force's heroes: [Hero(secret_name='Dive Wilson', id=1, age=None, name='Deadpond')]
# 2021-09-08 17:29:44,165 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:29:44,168 INFO sqlalchemy.engine.Engine [cached since 0.1725s ago] (3,)
# 2021-09-08 17:29:44,174 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team, heroteamlink
# WHERE ? = heroteamlink.hero_id AND team.id = heroteamlink.team_id
# 2021-09-08 17:29:44,175 INFO sqlalchemy.engine.Engine [cached since 336.1s ago] (3,)
# Reverted Spider-Boy's teams: [Team(name='Preventers', id=2, headquarters='Sharp Tower')]
# 2021-09-08 17:29:44,183 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ### [Link Model with Extra Fields](https://sqlmodel.tiangolo.com/tutorial/many-to-many/link-with-extra-fields/)

# %%
# RESTART KERNEL, RE-IMPORT AND REMOVE DATABASE.DB
class HeroTeamLink(SQLModel, table=True):
    team_id: Optional[int] = Field(default=None, foreign_key="team.id", primary_key=True)
    hero_id: Optional[int] = Field(default=None, foreign_key="hero.id", primary_key=True)
    is_training: bool = False

    team: "Team" = Relationship(back_populates="hero_links")
    hero: "Hero" = Relationship(back_populates="team_links")


class Team(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    headquarters: str

    hero_links: List[HeroTeamLink] = Relationship(back_populates="team")


class Hero(SQLModel, table=True):
    id: Optional[int] = Field(default=None, primary_key=True)
    name: str
    secret_name: str
    age: Optional[int] = None

    team_links: List[HeroTeamLink] = Relationship(back_populates="hero")

# %%
create_db_and_tables()
# Out:
# 2021-09-08 17:31:16,098 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:31:16,099 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("heroteamlink")
# 2021-09-08 17:31:16,100 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:31:16,101 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("heroteamlink")
# 2021-09-08 17:31:16,102 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:31:16,103 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("team")
# 2021-09-08 17:31:16,104 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:31:16,105 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("team")
# 2021-09-08 17:31:16,106 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:31:16,107 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("hero")
# 2021-09-08 17:31:16,108 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:31:16,109 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("hero")
# 2021-09-08 17:31:16,109 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-09-08 17:31:16,111 INFO sqlalchemy.engine.Engine
# CREATE TABLE team (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	headquarters VARCHAR NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-09-08 17:31:16,112 INFO sqlalchemy.engine.Engine [no key 0.00108s] ()
# 2021-09-08 17:31:16,188 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_name ON team (name)
# 2021-09-08 17:31:16,188 INFO sqlalchemy.engine.Engine [no key 0.00068s] ()
# 2021-09-08 17:31:16,282 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_headquarters ON team (headquarters)
# 2021-09-08 17:31:16,284 INFO sqlalchemy.engine.Engine [no key 0.00136s] ()
# 2021-09-08 17:31:16,399 INFO sqlalchemy.engine.Engine CREATE INDEX ix_team_id ON team (id)
# 2021-09-08 17:31:16,400 INFO sqlalchemy.engine.Engine [no key 0.00065s] ()
# 2021-09-08 17:31:16,511 INFO sqlalchemy.engine.Engine
# CREATE TABLE hero (
# 	id INTEGER,
# 	name VARCHAR NOT NULL,
# 	secret_name VARCHAR NOT NULL,
# 	age INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2021-09-08 17:31:16,513 INFO sqlalchemy.engine.Engine [no key 0.00127s] ()
# 2021-09-08 17:31:16,618 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_id ON hero (id)
# 2021-09-08 17:31:16,621 INFO sqlalchemy.engine.Engine [no key 0.00277s] ()
# 2021-09-08 17:31:16,757 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_name ON hero (name)
# 2021-09-08 17:31:16,760 INFO sqlalchemy.engine.Engine [no key 0.00315s] ()
# 2021-09-08 17:31:16,873 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_secret_name ON hero (secret_name)
# 2021-09-08 17:31:16,874 INFO sqlalchemy.engine.Engine [no key 0.00110s] ()
# 2021-09-08 17:31:16,990 INFO sqlalchemy.engine.Engine CREATE INDEX ix_hero_age ON hero (age)
# 2021-09-08 17:31:16,991 INFO sqlalchemy.engine.Engine [no key 0.00076s] ()
# 2021-09-08 17:31:17,097 INFO sqlalchemy.engine.Engine
# CREATE TABLE heroteamlink (
# 	team_id INTEGER,
# 	hero_id INTEGER,
# 	is_training BOOLEAN,
# 	PRIMARY KEY (team_id, hero_id),
# 	FOREIGN KEY(team_id) REFERENCES team (id),
# 	FOREIGN KEY(hero_id) REFERENCES hero (id)
# )
#
#
# 2021-09-08 17:31:17,098 INFO sqlalchemy.engine.Engine [no key 0.00085s] ()
# 2021-09-08 17:31:17,202 INFO sqlalchemy.engine.Engine CREATE INDEX ix_heroteamlink_team_id ON heroteamlink (team_id)
# 2021-09-08 17:31:17,203 INFO sqlalchemy.engine.Engine [no key 0.00089s] ()
# 2021-09-08 17:31:17,320 INFO sqlalchemy.engine.Engine CREATE INDEX ix_heroteamlink_is_training ON heroteamlink (is_training)
# 2021-09-08 17:31:17,320 INFO sqlalchemy.engine.Engine [no key 0.00068s] ()
# 2021-09-08 17:31:17,436 INFO sqlalchemy.engine.Engine CREATE INDEX ix_heroteamlink_hero_id ON heroteamlink (hero_id)
# 2021-09-08 17:31:17,436 INFO sqlalchemy.engine.Engine [no key 0.00051s] ()
# 2021-09-08 17:31:17,543 INFO sqlalchemy.engine.Engine COMMIT

# %%
def create_heroes():
    with Session(engine) as session:
        team_preventers = Team(name="Preventers", headquarters="Sharp Tower")
        team_z_force = Team(name="Z-Force", headquarters="Sister Margaret’s Bar")

        hero_deadpond = Hero(
            name="Deadpond",
            secret_name="Dive Wilson",
        )
        hero_rusty_man = Hero(
            name="Rusty-Man",
            secret_name="Tommy Sharp",
            age=48,
        )
        hero_spider_boy = Hero(
            name="Spider-Boy",
            secret_name="Pedro Parqueador",
        )

        deadpond_team_z_link = HeroTeamLink(team=team_z_force, hero=hero_deadpond)
        deadpond_preventers_link = HeroTeamLink(
            team=team_preventers, hero=hero_deadpond, is_training=True
        )

        spider_boy_preventers_link = HeroTeamLink(
            team=team_preventers, hero=hero_spider_boy, is_training=True
        )
        rusty_man_preventers_link = HeroTeamLink(
            team=team_preventers, hero=hero_rusty_man
        )

        session.add(deadpond_team_z_link)
        session.add(deadpond_preventers_link)
        session.add(spider_boy_preventers_link)
        session.add(rusty_man_preventers_link)
        session.commit()

        for link in team_z_force.hero_links:
            cprint(f"Z-Force hero: {link.hero} is training: {link.is_training}", "green")

        for link in team_preventers.hero_links:
            cprint(
                f"Preventers hero: {link.hero} is training: {link.is_training}", "green"
            )


create_heroes()
# Out:
# 2021-09-08 17:31:18,832 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:31:18,834 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:31:18,834 INFO sqlalchemy.engine.Engine [generated in 0.00069s] ('Deadpond', 'Dive Wilson', None)
# 2021-09-08 17:31:18,838 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:31:18,838 INFO sqlalchemy.engine.Engine [cached since 0.004492s ago] ('Spider-Boy', 'Pedro Parqueador', None)
# 2021-09-08 17:31:18,839 INFO sqlalchemy.engine.Engine INSERT INTO hero (name, secret_name, age) VALUES (?, ?, ?)
# 2021-09-08 17:31:18,840 INFO sqlalchemy.engine.Engine [cached since 0.005919s ago] ('Rusty-Man', 'Tommy Sharp', 48)
# 2021-09-08 17:31:18,841 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:31:18,842 INFO sqlalchemy.engine.Engine [generated in 0.00059s] ('Z-Force', 'Sister Margaret’s Bar')
# 2021-09-08 17:31:18,843 INFO sqlalchemy.engine.Engine INSERT INTO team (name, headquarters) VALUES (?, ?)
# 2021-09-08 17:31:18,844 INFO sqlalchemy.engine.Engine [cached since 0.002808s ago] ('Preventers', 'Sharp Tower')
# 2021-09-08 17:31:18,846 INFO sqlalchemy.engine.Engine INSERT INTO heroteamlink (team_id, hero_id, is_training) VALUES (?, ?, ?)
# 2021-09-08 17:31:18,847 INFO sqlalchemy.engine.Engine [generated in 0.00073s] ((1, 1, 0), (2, 1, 1), (2, 2, 1), (2, 3, 0))
# 2021-09-08 17:31:18,848 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:31:19,067 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:31:19,069 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:31:19,069 INFO sqlalchemy.engine.Engine [generated in 0.00078s] (1,)
# 2021-09-08 17:31:19,072 INFO sqlalchemy.engine.Engine SELECT heroteamlink.team_id AS heroteamlink_team_id, heroteamlink.hero_id AS heroteamlink_hero_id, heroteamlink.is_training AS heroteamlink_is_training
# FROM heroteamlink
# WHERE ? = heroteamlink.team_id
# 2021-09-08 17:31:19,073 INFO sqlalchemy.engine.Engine [generated in 0.00059s] (1,)
# 2021-09-08 17:31:19,075 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:31:19,076 INFO sqlalchemy.engine.Engine [generated in 0.00061s] (1,)
# Z-Force hero: name='Deadpond' age=None id=1 secret_name='Dive Wilson' is training: False
# 2021-09-08 17:31:19,078 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:31:19,078 INFO sqlalchemy.engine.Engine [cached since 0.009687s ago] (2,)
# 2021-09-08 17:31:19,080 INFO sqlalchemy.engine.Engine SELECT heroteamlink.team_id AS heroteamlink_team_id, heroteamlink.hero_id AS heroteamlink_hero_id, heroteamlink.is_training AS heroteamlink_is_training
# FROM heroteamlink
# WHERE ? = heroteamlink.team_id
# 2021-09-08 17:31:19,080 INFO sqlalchemy.engine.Engine [cached since 0.00843s ago] (2,)
# Preventers hero: name='Deadpond' age=None id=1 secret_name='Dive Wilson' is training: True
# 2021-09-08 17:31:19,082 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:31:19,083 INFO sqlalchemy.engine.Engine [cached since 0.007538s ago] (2,)
# Preventers hero: name='Spider-Boy' age=None id=2 secret_name='Pedro Parqueador' is training: True
# 2021-09-08 17:31:19,084 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:31:19,084 INFO sqlalchemy.engine.Engine [cached since 0.00932s ago] (3,)
# Preventers hero: name='Rusty-Man' age=48 id=3 secret_name='Tommy Sharp' is training: False
# 2021-09-08 17:31:19,086 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
def update_heroes():
    with Session(engine) as session:
        hero_spider_boy = session.exec(
            select(Hero).where(Hero.name == "Spider-Boy")
        ).one()
        team_z_force = session.exec(select(Team).where(Team.name == "Z-Force")).one()

        spider_boy_z_force_link = HeroTeamLink(
            team=team_z_force, hero=hero_spider_boy, is_training=True
        )

        team_z_force.hero_links.append(spider_boy_z_force_link)
        session.add(team_z_force)
        session.commit()

        cprint(f"Updated Spider-Boy's Teams: {hero_spider_boy.team_links}", "green")
        cprint(f"Z-Force heroes: {team_z_force.hero_links}", "green")

        for link in hero_spider_boy.team_links:
            if link.team.name == "Preventers":
                link.is_training = False

        session.add(hero_spider_boy)
        session.commit()

        for link in hero_spider_boy.team_links:
            cprint(
                f"Spider-Boy team: {link.team} is training: {link.is_training}", "green"
            )


update_heroes()
# Out:
# 2021-09-08 17:31:22,607 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:31:22,608 INFO sqlalchemy.engine.Engine SELECT hero.id, hero.name, hero.secret_name, hero.age
# FROM hero
# WHERE hero.name = ?
# 2021-09-08 17:31:22,608 INFO sqlalchemy.engine.Engine [no key 0.00043s] ('Spider-Boy',)
# 2021-09-08 17:31:22,610 INFO sqlalchemy.engine.Engine SELECT team.id, team.name, team.headquarters
# FROM team
# WHERE team.name = ?
# 2021-09-08 17:31:22,611 INFO sqlalchemy.engine.Engine [no key 0.00080s] ('Z-Force',)
# 2021-09-08 17:31:22,614 INFO sqlalchemy.engine.Engine INSERT INTO heroteamlink (team_id, hero_id, is_training) VALUES (?, ?, ?)
# 2021-09-08 17:31:22,615 INFO sqlalchemy.engine.Engine [generated in 0.00079s] (1, 2, 1)
# 2021-09-08 17:31:22,711 INFO sqlalchemy.engine.Engine SELECT heroteamlink.team_id AS heroteamlink_team_id, heroteamlink.hero_id AS heroteamlink_hero_id, heroteamlink.is_training AS heroteamlink_is_training
# FROM heroteamlink
# WHERE ? = heroteamlink.team_id
# 2021-09-08 17:31:22,711 INFO sqlalchemy.engine.Engine [cached since 3.639s ago] (1,)
# 2021-09-08 17:31:22,713 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:31:22,813 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:31:22,814 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:31:22,814 INFO sqlalchemy.engine.Engine [cached since 3.739s ago] (2,)
# 2021-09-08 17:31:22,816 INFO sqlalchemy.engine.Engine SELECT heroteamlink.team_id AS heroteamlink_team_id, heroteamlink.hero_id AS heroteamlink_hero_id, heroteamlink.is_training AS heroteamlink_is_training
# FROM heroteamlink
# WHERE ? = heroteamlink.hero_id
# 2021-09-08 17:31:22,816 INFO sqlalchemy.engine.Engine [generated in 0.00044s] (2,)
# Updated Spider-Boy's Teams: [HeroTeamLink(is_training=True, team_id=2, hero_id=2), HeroTeamLink(is_training=True, team_id=1, hero_id=2)]
# 2021-09-08 17:31:22,819 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:31:22,819 INFO sqlalchemy.engine.Engine [cached since 3.75s ago] (1,)
# 2021-09-08 17:31:22,820 INFO sqlalchemy.engine.Engine SELECT heroteamlink.team_id AS heroteamlink_team_id, heroteamlink.hero_id AS heroteamlink_hero_id, heroteamlink.is_training AS heroteamlink_is_training
# FROM heroteamlink
# WHERE ? = heroteamlink.team_id
# 2021-09-08 17:31:22,821 INFO sqlalchemy.engine.Engine [cached since 3.749s ago] (1,)
# Z-Force heroes: [HeroTeamLink(is_training=False, team_id=1, hero_id=1), HeroTeamLink(is_training=True, team_id=1, hero_id=2)]
# 2021-09-08 17:31:22,823 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:31:22,823 INFO sqlalchemy.engine.Engine [generated in 0.00067s] (2,)
# 2021-09-08 17:31:22,827 INFO sqlalchemy.engine.Engine UPDATE heroteamlink SET is_training=? WHERE heroteamlink.team_id = ? AND heroteamlink.hero_id = ?
# 2021-09-08 17:31:22,827 INFO sqlalchemy.engine.Engine [generated in 0.00052s] (0, 2, 2)
# 2021-09-08 17:31:22,829 INFO sqlalchemy.engine.Engine COMMIT
# 2021-09-08 17:31:22,954 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-09-08 17:31:22,955 INFO sqlalchemy.engine.Engine SELECT hero.id AS hero_id, hero.name AS hero_name, hero.secret_name AS hero_secret_name, hero.age AS hero_age
# FROM hero
# WHERE hero.id = ?
# 2021-09-08 17:31:22,955 INFO sqlalchemy.engine.Engine [cached since 3.88s ago] (2,)
# 2021-09-08 17:31:22,957 INFO sqlalchemy.engine.Engine SELECT heroteamlink.team_id AS heroteamlink_team_id, heroteamlink.hero_id AS heroteamlink_hero_id, heroteamlink.is_training AS heroteamlink_is_training
# FROM heroteamlink
# WHERE ? = heroteamlink.hero_id
# 2021-09-08 17:31:22,958 INFO sqlalchemy.engine.Engine [cached since 0.1421s ago] (2,)
# 2021-09-08 17:31:22,959 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:31:22,960 INFO sqlalchemy.engine.Engine [cached since 0.1376s ago] (2,)
# Spider-Boy team: name='Preventers' id=2 headquarters='Sharp Tower' is training: False
# 2021-09-08 17:31:22,962 INFO sqlalchemy.engine.Engine SELECT team.id AS team_id, team.name AS team_name, team.headquarters AS team_headquarters
# FROM team
# WHERE team.id = ?
# 2021-09-08 17:31:22,963 INFO sqlalchemy.engine.Engine [cached since 3.894s ago] (1,)
# Spider-Boy team: id=1 name='Z-Force' headquarters='Sister Margaret’s Bar' is training: True
# 2021-09-08 17:31:22,965 INFO sqlalchemy.engine.Engine ROLLBACK
